# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
# Libraries
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## Challenge 1
#
# #### The data we will use in this challenge is:

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# #### Plot (x, y) and (x, z).
# There are 2 ways of doing this. Do in both ways.
#
# **Hint**: Check out the nrows, ncols and index arguments of subplots.
#
# Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
# Method 1
fig, ax1 = plt.subplots(figsize = (10, 7))
ax1.set_title("Challenge 1 - Method 1", fontsize=25)
ax1.plot(x, y, label='x-y')
ax1.plot(x, z, label='x-z')
ax1.legend()

# %% [markdown]
# #### Use plt.subplots(nrows=1, ncols=2) to create the plot.

# %%
# Method 2
fig2, axes2 = plt.subplots(1, 2, figsize = (10, 7))
fig2.suptitle("Challenge 1 - Method 2", fontsize=18)
axes2[0].plot(x,y, label="x, y")
axes2[1].plot(x,z, label="x, z", c='orange')

# %% [markdown]
# #### Use your previous code but now, resize your plot.
# **Hint**: Add the figsize argument in plt.subplots().
#
# If you want, try to add a title to the plot or even axes labels. You can also play with the fontweight and fontsize of the titles and labels.

# %%
# your code here
fig3, axes3 = plt.subplots(1, 2, figsize = (15, 5))
fig3.suptitle("Challenge 1 - Method 2 Resized", fontsize=18)
axes3[0].plot(x,y, label="x, y")
axes3[0].set_title("x, y")
axes3[1].plot(x,z, label="x, z", c='orange')
axes3[1].set_title("x, z")
# Out:
# Text(0.5, 1.0, 'x, z')

# %% [markdown]
# #### Now you will have to plot both $y=x^2$ and $y=e^x$ in the same plot. Create two subplots and use a normal scale in the first one and a logarithmic scale in the second one.
# **Hint**: Use `set_xscale` and `set_yscale`.

# %%
# your code here
x = np.arange(0,100)
y1 = x**2
y2 = math.e**x
fig4, axes4 = plt.subplots(1, 2, figsize=(15,5))
fig4.suptitle('Challenge 1 - Normal & Logaritmic Scales')
axes4[0].plot(x,y1, label="Normal Scale")
axes4[0].set_title("Normal Scale")
axes4[0].set_xscale('linear')
axes4[1].plot(x,y2, label="Logaritmic Scale", c='orange')
axes4[1].set_title("Logaritmic Scale")
axes4[1].set_yscale('log')

# %% [markdown]
# #### As a bonus challenge, try to add a legend to the plot.

# %%
# your code here
x = np.arange(0,100)
y1 = x**2
y2 = math.e**x
fig4, axes4 = plt.subplots(1, 2, figsize=(15,5))
fig4.suptitle('Challenge 1 - Normal & Logaritmic Scales')
axes4[0].plot(x,y1, label="x**2")
axes4[0].set_title("Normal Scale")
axes4[0].set_xscale('linear')
axes4[1].plot(x,y2, label="e**2", c='orange')
axes4[1].set_title("Logaritmic Scale")
axes4[1].set_yscale('log')
for ax in axes4:
    ax.legend()

# %% [markdown]
# ## Challenge 2
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
# your code here
fitbit = pd.read_csv('../Datasets_CSV/Fitbit2.csv')
fitbit
# Out:
#            Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 0    2015-05-08            1934    905      0.65       0              1.355
# 1    2015-05-09            3631  18925     14.11       4            611.000
# 2    2015-05-10            3204  14228     10.57       1            602.000
# 3    2015-05-11            2673   6756      5.02       8            749.000
# 4    2015-05-12            2495    502      3.73       1            876.000
# ..          ...             ...    ...       ...     ...                ...
# 362  2016-05-03            3796  18588     14.13      16            599.000
# 363  2016-05-04            3525  16382     12.39      16            684.000
# 364  2016-05-05            3649  21913     16.40      19            701.000
# 365  2016-05-06            3539  19023     14.79      15            575.000
# 366  2016-05-07             304   9526      7.08       2            564.000
#
# ...

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays? All plots must be in the same jupyter notebook cell.
#
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
fig5, axes5 = plt.subplots(1, 2, figsize=(12,4))
fig5.suptitle('Steps by Month & Work/Weekend')
fit_months = fitbit.groupby("Months_encoded")["Steps"].median()
fit_work = fitbit[fitbit["Work_or_Weekend"] == 0].groupby(fitbit['Days'])['Steps'].count()
# MEDIAN STEPS BY MONTH_ENCODED
# your code here
plt.sca(axes5[0])
axes5[0].plot(fit_months.index, fit_months)
plt.xticks(range(13), ["","Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"],rotation= "vertical")

# MEDIAN STEPS BY WORK_OR_WEEKEND
# your code here
plt.sca(axes5[1])
axes5[1].bar(fit_work.index, fit_work)
plt.xticks(range(2), ["Weekend","Workdays"])
# Out:
# ([<matplotlib.axis.XTick at 0x7fd9b978f0a0>,
# ...
#  [Text(0, 0, 'Weekend'), Text(1, 0, 'Workdays')])

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
# your code here
features = ["Minutes Lightly Active", "Minutes Very Active", "Minutes Sedentary"]
i = 0

fig6 , axes6 = plt.subplots(1, 3, figsize = (15,7))
fig6.suptitle('3 scatter plots', fontsize = 20)

for feature in features:  
    axes6[i].scatter(fitbit[feature], fitbit["Steps"],  label = feature)
    axes6[i].set_title(feature)
    i+=1

# %% [markdown]
# ## Challenge 3
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
# your code here
titanic = pd.read_csv('../Datasets_CSV/titanic.csv')
titanic
# Out:
#       PassengerId  Survived  Pclass  \
# 0               1       0.0       3
# 1               2       1.0       1
# 2               3       1.0       3
# 3               4       1.0       1
# 4               5       0.0       3
# ...           ...       ...     ...
# 1304         1305       NaN       3
# 1305         1306       NaN       1
# 1306         1307       NaN       3
# 1307         1308       NaN       3
# 1308         1309       NaN       3
#
#                                                    Name  Gender        Age  \
# 0                               Braund, Mr. Owen Harris    male  22.000000
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                                Heikkinen, Miss. Laina  female  26.000000
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                              Allen, Mr. William Henry    male  35.000000
# ...

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
# your code here
titanic.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
# NUMERICAL VARIABLES
# your code here
titanic.select_dtypes(include=['int64', 'float64'])
# Out:
#       PassengerId  Survived  Pclass        Age  SibSp  Parch      Fare
# 0               1       0.0       3  22.000000      1      0    7.2500
# 1               2       1.0       1  38.000000      1      0   71.2833
# 2               3       1.0       3  26.000000      0      0    7.9250
# 3               4       1.0       1  35.000000      1      0   53.1000
# 4               5       0.0       3  35.000000      0      0    8.0500
# ...           ...       ...     ...        ...    ...    ...       ...
# 1304         1305       NaN       3  29.513190      0      0    8.0500
# 1305         1306       NaN       1  39.000000      0      0  108.9000
# 1306         1307       NaN       3  38.500000      0      0    7.2500
# 1307         1308       NaN       3  29.513190      0      0    8.0500
# 1308         1309       NaN       3  25.315435      1      1   22.3583
#
# [1309 rows x 7 columns]

# %%
# CATEGORICAL VARIABLES
# your code here
titanic.select_dtypes(include=['object'])
# Out:
#                                                    Name  Gender  \
# 0                               Braund, Mr. Owen Harris    male
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                                Heikkinen, Miss. Laina  female
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                              Allen, Mr. William Henry    male
# ...                                                 ...     ...
# 1304                                 Spector, Mr. Woolf    male
# 1305                       Oliva y Ocana, Dona. Fermina  female
# 1306                       Saether, Mr. Simon Sivertsen    male
# 1307                                Ware, Mr. Frederick    male
# 1308                           Peter, Master. Michael J    male
#
#                   Ticket Cabin Embarked
# 0              A/5 21171    U0        S
# 1               PC 17599   C85        C
# 2       STON/O2. 3101282    U0        S
# ...

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
# your code here
fig7, axes7 = plt.subplots(figsize=(12,6))
sns.set_style(style='whitegrid')

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
# your code here
titanic['Age'].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
# your code here
fig8, axes8 = plt.subplots(nrows=1, ncols=3, figsize =(20,5))
bins = [10,20,50]

for i in range(3):
    plt.sca(axes8[i])
    titanic["Age"].hist(bins=bins[i])
    plt.title(f"Age distribution with {bins[i]} bins", fontsize=15)

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
"""
The more bins are used, the more specific the plot is.
"""

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
# your code here
fig9, axes9 = plt.subplots(nrows=1, ncols=1, figsize =(20,5))
ages = titanic['Age']
age_index = ages.index
plt.scatter(x=ages, y=age_index, alpha=0.3)
plt.title("Age distribution of Titanic", fontsize=15, fontweight="bold")
plt.xlabel("ages")
plt.ylabel("passengers")
# Out:
# Text(0, 0.5, 'passengers')

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here
gender = titanic['Gender'].value_counts()
gender_index = gender.index
plt.bar(gender_index, gender)
plt.title("Gender of passengers", fontsize= 15)
plt.ylabel("passengers")
# Out:
# Text(0, 0.5, 'passengers')

# %%
# Method 2 - seaborn
# your code here
sns.barplot(x=gender_index, y=gender).set_title("Genre of passengers", fontsize=15)
plt.ylabel("passengers")
# Out:
# Text(0, 0.5, 'passengers')

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
# your code here
pclass = titanic['Pclass'].value_counts().sort_values()
pclass_index = ["first", "second", "third"]
sns.barplot(x=pclass_index, y=pclass).set_title("Available passenger classes", fontsize=15)
plt.ylabel("passengers")
# Out:
# Text(0, 0.5, 'passengers')

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
# your code here
sns.boxplot(x=titanic["Age"])
plt.title("Ages distribution of Titanic")
# Out:
# Text(0.5, 1.0, 'Ages distribution of Titanic')

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
"""
The boxplot show that the mean of the ages is arround 28-30. It also show that the minimum age was 0 and the maximum 80. 
Also show that most of the passengers were between 20 and 38 years old. The distribution is skewed to the left.
"""

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
# your code here

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
"""
your comments here
"""

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here
fix10, axes10 = plt.subplots(figsize=(12,5))
axes10.scatter(x=titanic["Fare"], y=titanic["Age"], alpha=0.3)
axes10.set_title("Linear relationship between fare and age of the passengers", fontsize="14")
plt.xlabel("Fare")
plt.ylabel("Age")
# Out:
# Text(0, 0.5, 'Age')

# %%
# Method 2 - seaborn
# your code here

# Method 2 - seaborn
# your code here
fix11, axes11 = plt.subplots(figsize=(12,5))
sns.scatterplot(x=titanic["Fare"], y=titanic["Age"], alpha=0.4)
axes11.set_title("Linear relationship between fare and age of the passengers", fontsize="14")
# Out:
# Text(0.5, 1.0, 'Linear relationship between fare and age of the passengers')

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
# your code here
corr = titanic.corr()

# %%
fix12, axes12 = plt.subplots(figsize=(10,5))
axes12 = sns.heatmap(corr, vmax=1, center=0, cmap="Blues", square=True)
axes12.set_title("Correlation plot", fontsize=14)
# Out:
# Text(0.5, 1.0, 'Correlation plot')

# %% [markdown]
# #### What are the most correlated features?

# %%
"""
The most correlated features are pclass and fare, which makes sense because the higher the class, the higher the fare.
"""

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
# your code here
fix13, axes13 = plt.subplots(figsize=(5,5))
sns.boxplot(x=titanic["Pclass"], y=titanic["Age"], data=titanic)
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='Age'>

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
# your code here
g = sns.FacetGrid(data=titanic, col="Gender")
g.map(plt.hist, "Age")
